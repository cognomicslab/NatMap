# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import image
import numpy as np
import cv2 as cv
import os
from datetime import datetime
import time
from scipy.spatial.distance import pdist, squareform 
#from scipy.stats import spearmanr

# %%
# laosheng_s1
# set dir
parent_folder = '/bigvault/Projects/sea_hero/LOCdata/validation/laosheng_s1'
save_folder = '/bigvault/Projects/sea_hero/LOCdata/article/Remap_article/results/data/laosheng_s1'
os.makedirs(save_folder, exist_ok=True)

cal_save_path = os.path.join(save_folder, 'cal_dist.csv')
bidi_save_path = os.path.join(save_folder, 'bidi_raw.csv')

subfolders = [f.path for f in os.scandir(parent_folder) if f.is_dir()]

results = []
bidi_raw = pd.DataFrame()

for subfolder in subfolders:
    subjid = os.path.basename(subfolder)

    # read data
    trackinfo_file_path = os.path.join(subfolder, 'trackinfo.txt')
    dat = pd.read_json(trackinfo_file_path)
    userinfo_file_path = os.path.join(subfolder, 'userinfo.txt')
    layout_dat = pd.read_json(userinfo_file_path, orient='index').transpose()

    # basic info
    name = layout_dat['name'][0]
    sex = layout_dat['sex'][0]

    # age
    dob = layout_dat['dateOfBirth'][0]
    dob_year = int(dob[:4])
    dob_month = int(dob[4:6])
    test_time = layout_dat['beginTime'][0]
    test_year = int(test_time.split('/')[0])
    test_month = int(test_time.split('/')[1])
    age = round((test_year - dob_year) + (test_month - dob_month) / 12.0, 1)

    # Test_date
    test_time_dt = datetime.strptime(test_time, "%Y/%m/%d %H:%M:%S")
    test_date = test_time_dt.strftime("%Y/%m/%d")

    # Duration
    time_start = datetime.strptime(layout_dat['beginTime'][0], '%Y/%m/%d %H:%M:%S')
    time_end = datetime.strptime(layout_dat['endTime'][0], '%Y/%m/%d %H:%M:%S')
    time_dur = (time_end - time_start).total_seconds()


    # Dist_Avg, Dist_Std
    n_loc = len(layout_dat['localInfos'][0])
    xs, ys, x0s, y0s, dists = [], [], [], [], []

    for i_loc in range(n_loc):
        xs.append(layout_dat['localInfos'][0][i_loc]['x'])
        ys.append(layout_dat['localInfos'][0][i_loc]['y'])
        x0s.append(layout_dat['targetInfos'][0][i_loc]['x'])
        y0s.append(layout_dat['targetInfos'][0][i_loc]['y'])

        #time for each picture for everyone, 
        #track_dat = dat.trackInfos[i_loc]['localInfos']
        #times.append(len(track_dat)/10)
        
        dists.append(np.sqrt((xs[i_loc] - x0s[i_loc]) ** 2 + (ys[i_loc] - y0s[i_loc]) ** 2))

    dist_avg = np.mean(dists)
    dist_std = np.std(dists)

    # bidi_raw for bidiregression
    bidi_raw_0 = pd.DataFrame({
        'Name': [name] * n_loc,
        'xloc': xs,
        'yloc': ys,
        'xorig': x0s,
        'yorig': y0s,
        'distance': dists
        #'time': times
    })
    bidi_raw = pd.concat([bidi_raw, bidi_raw_0], ignore_index=True)

    # Track_Avg, Track_Std
    track_dist_list = []
    n_loc_track = dat.trackInfos.shape[0]
    for i_loc in range(n_loc_track):
        track_dat = dat.trackInfos[i_loc]['localInfos']
        n_point = len(track_dat)
        x_list = [p['x'] for p in track_dat]
        y_list = [p['y'] for p in track_dat]

        total_dist = sum(((x_list[i] - x_list[i-1]) ** 2 + (y_list[i] - y_list[i-1]) ** 2) ** 0.5 for i in range(1, n_point))
        track_dist_list.append(total_dist)

    mean_track_dist = np.mean(track_dist_list)
    std_track_dist = np.std(track_dist_list)

    # save data
    cal_out = {
        'Name': name,
        'Age': age,
        'Sex': sex,
        'Test_date': test_date,
        'Duration': time_dur,
        'Dist_Avg': dist_avg,
        'Dist_Std': dist_std,
        'Track_Avg': mean_track_dist,
        'Track_Std': std_track_dist
    }

    results.append(cal_out)
    print(f"Processed {subjid}")

# to DataFrame and save file
df = pd.DataFrame(results)
df.to_csv(cal_save_path, index=False)
bidi_raw.to_csv(bidi_save_path, index=False)

print(f"Saved combined results to {save_folder}")
# Out:
# Processed baoran_20240305-08-08-01
# Processed caichenyang_20240119-05-58-17
# Processed chenanqi_20240305-07-02-09
# Processed chenqiyang_20231220-01-07-40
# Processed chenquan_20231220-05-06-46
# Processed chenrouhan_20240228-04-38-08
# Processed chenxintong_20240302-11-10-13
# Processed chenxin_20240229-07-57-28
# Processed chenyingqi_20231201-04-29-44
# Processed chenzhedong_20240118-03-36-57
# Processed daiweitao_20240115-07-27-23
# Processed dengrudan_20240118-05-47-21
# Processed dengyang_20240229-06-06-00
# Processed dingxukai_20240123-04-46-42
# Processed duanjinghui_20240117-07-04-49
# Processed dufeixuan_20240303-09-09-16
# Processed dujunan_20240229-06-17-11
# Processed dulijun_20240305-06-11-47
# Processed fangjiayi_20231203-12-02-49
# Processed fanzhiliang_20240320-06-36-38
# Processed fuyihan_20231213-06-07-57
# Processed gangchenming_20240302-10-02-03
# Processed gaomeiyi_20231201-02-02-27
# Processed gaoshuolian_20231203-09-38-11
# Processed gaoyushi_20240115-08-15-16
# Processed gesangciren_20240115-06-09-00
# Processed gujun_20240115-07-04-15
# Processed guocong_20231210-11-39-19
# Processed guoyeye_20240302-11-08-29
# Processed hanyue_20240306-06-43-03
# Processed heguirong_20240118-06-01-03
# Processed hejiayi_20231228-08-23-21
# Processed hongbaicheng_20240118-02-42-52
# Processed hongjiayu_20231220-12-59-51
# Processed huangyanran_20240303-09-32-47
# Processed huaxinran_20240119-10-25-27
# Processed hutianfeng_20231213-09-34-23
# Processed jianglai_20240119-06-20-29
# Processed jijiamin_20240118-04-08-13
# Processed jingyubo_20240315-06-01-26
# Processed jinxinyue_20240305-08-36-07
# Processed kepeirui_20240303-09-11-41
# Processed leiyu_20240115-07-40-12
# Processed liaojiaming_20240228-04-26-15
# Processed lihenghui_20231213-09-49-18
# Processed lijialin_20240118-04-38-37
# Processed lijuanyu_20240229-11-36-17
# Processed limingze_20240228-04-37-03
# Processed linyi_20240115-05-49-58
# Processed linzhenghui_20231213-06-00-30
# Processed linzijing_20240306-07-39-01
# Processed liumingting_20231213-11-50-09
# Processed liuqiuyi_20231208-04-19-18
# Processed liusongting_20231213-10-02-26
# Processed liuwanqing_20240303-11-36-55
# Processed liuxiangyi_20231201-01-13-51
# Processed liuyuting_20240115-06-47-57
# Processed liuyutong_20231201-04-26-27
# Processed liuzhanxu_20231228-05-34-09
# Processed liyufeng_20240118-05-34-39
# Processed luzhangjing_20240309-10-00-24
# Processed maluyang_20240306-06-22-23
# Processed maoshenpei_20240118-03-26-12
# Processed maxin_20240123-02-37-52
# Processed meishaoxian_20240315-06-15-22
# Processed murediliabula_20240302-11-06-51
# Processed niejingting_20231203-10-43-28
# Processed ouyangjing_20240309-11-31-38
# Processed panyiying_20240306-06-12-33
# Processed qianjiajun_20231220-02-41-59
# Processed qiantaiming_20240302-10-31-32
# Processed qijiahao_20240115-06-30-00
# Processed qiumingen_20231201-03-22-57
# Processed qiuzixuan_20240123-03-41-56
# Processed renminfeng_20240229-06-59-25
# Processed shaojiayi_20240120-08-21-34
# Processed shixuanxuan_20231228-06-04-48
# Processed sunyuewei_20240306-06-09-15
# Processed suzhe_20240313-06-10-04
# Processed tangminke_20240309-11-43-19
# Processed tangxinai_20231203-10-58-20
# Processed tangyi_20240104-05-44-03
# Processed tangyufei_20231213-10-07-29
# Processed tangzhucan_20240229-11-46-07
# Processed tanxinyi_20240302-10-12-29
# Processed taolv_20240315-06-51-53
# Processed tengyujie_20240306-06-14-39
# Processed tukai_20231213-12-01-37
# Processed tulugenaiyi_20231208-04-14-19
# Processed wangfangqi_20240309-09-07-03
# Processed wanghongru_20240314-09-11-00
# Processed wangjingen_20231201-03-29-48
# Processed wangjunbin_20240228-01-29-46
# Processed wangqian_20231210-11-42-52
# Processed wangshiming_20240306-06-36-26
# Processed wangwenqi_20231201-01-42-54
# Processed wangxiaoxiao_20240229-06-59-30
# Processed wangying_20231203-10-15-28
# Processed wuminqin_20240118-05-57-34
# Processed wuzhiwei_20240229-06-14-01
# Processed wuzunan_20240314-06-08-36
# Processed xianghuiru_20231228-05-38-55
# Processed xiazhenyang_20240309-09-23-08
# Processed xingyiyang_20231213-07-07-09
# Processed xiongtianyu_20231223-06-31-34
# Processed xuejia_20240309-11-27-32
# Processed xujiawei_20240306-06-47-33
# Processed xulingna_20240116-06-29-29
# Processed xuyuyi_20240309-10-39-04
# Processed yangchenyi_20231223-06-00-39
# Processed yangdong_20240302-11-30-29
# Processed yangkun_20240305-08-40-01
# Processed yangqian_20231220-03-24-50
# Processed yangzhanchao_20240228-04-22-24
# Processed yantianran_20231228-09-44-04
# Processed Yehaiqing_20240122-11-30-58
# Processed yejiawen_20231208-04-36-10
# Processed yexinying_20231210-11-17-12
# Processed yeziyu_20240309-10-27-32
# Processed yujunjie_20240104-05-42-28
# Processed yumingyue_20231208-04-12-05
# Processed yushengyi_20231213-12-04-38
# Processed yuzihan_20240104-06-05-01
# Processed zengzilu_20240229-08-03-54
# Processed zhangjieyu_20240306-06-13-40
# Processed zhangkejiong_20231223-05-36-54
# Processed zhangsikun_20240315-07-38-33
# Processed zhangxiaoning_20231213-06-22-44
# Processed zhangxiaoqi_20231210-11-08-13
# Processed zhangyixi_20240120-06-40-55
# Processed zhangyixuan_20231215-06-53-40
# Processed zhangzhihao_20240228-04-44-37
# Processed zhangzihan_20240303-11-07-50
# Processed zhangzihao_20231208-04-01-43
# Processed zhangzijiao_20240306-06-20-07
# Processed zhengjinqi_20240229-09-07-40
# Processed zhengxinying_20231203-10-37-06
# Processed zhouhuiling_20231223-06-05-19
# Processed zhoujiameng_20240315-07-49-03
# Processed zhoutianyu_20240302-11-12-31
# Processed zhouwenqing_20231228-07-02-47
# Processed zhouyujia_20231201-05-47-11
# Processed zhubinger_20240228-02-05-17
# Processed zhuyixuan_20240120-07-42-52
# Processed zhuzhiyuan_20240305-06-29-59
# Processed zijuansen_20240303-09-14-00
# Saved combined results to /bigvault/Projects/sea_hero/LOCdata/article/Remap_article/results/data/laosheng_s1

# %%
# laosheng_s2
# set dir
parent_folder = '/bigvault/Projects/sea_hero/LOCdata/validation/laosheng_s2'
save_folder = '/bigvault/Projects/sea_hero/LOCdata/article/Remap_article/results/data/laosheng_s2'
os.makedirs(save_folder, exist_ok=True)

cal_save_path = os.path.join(save_folder, 'cal_dist.csv')
bidi_save_path = os.path.join(save_folder, 'bidi_raw.csv')

subfolders = [f.path for f in os.scandir(parent_folder) if f.is_dir()]

results = []
bidi_raw = pd.DataFrame()

for subfolder in subfolders:
    subjid = os.path.basename(subfolder)

    # read data
    trackinfo_file_path = os.path.join(subfolder, 'trackinfo.txt')
    dat = pd.read_json(trackinfo_file_path)
    userinfo_file_path = os.path.join(subfolder, 'userinfo.txt')
    layout_dat = pd.read_json(userinfo_file_path, orient='index').transpose()

    # basic info
    name = layout_dat['name'][0]
    sex = layout_dat['sex'][0]

    # age
    dob = layout_dat['dateOfBirth'][0]
    dob_year = int(dob[:4])
    dob_month = int(dob[4:6])
    test_time = layout_dat['beginTime'][0]
    test_year = int(test_time.split('/')[0])
    test_month = int(test_time.split('/')[1])
    age = round((test_year - dob_year) + (test_month - dob_month) / 12.0, 1)

    # Test_date
    test_time_dt = datetime.strptime(test_time, "%Y/%m/%d %H:%M:%S")
    test_date = test_time_dt.strftime("%Y/%m/%d")

    # Duration
    time_start = datetime.strptime(layout_dat['beginTime'][0], '%Y/%m/%d %H:%M:%S')
    time_end = datetime.strptime(layout_dat['endTime'][0], '%Y/%m/%d %H:%M:%S')
    time_dur = (time_end - time_start).total_seconds()


    # Dist_Avg, Dist_Std
    n_loc = len(layout_dat['localInfos'][0])
    xs, ys, x0s, y0s, dists = [], [], [], [], []

    for i_loc in range(n_loc):
        xs.append(layout_dat['localInfos'][0][i_loc]['x'])
        ys.append(layout_dat['localInfos'][0][i_loc]['y'])
        x0s.append(layout_dat['targetInfos'][0][i_loc]['x'])
        y0s.append(layout_dat['targetInfos'][0][i_loc]['y'])

        #time for each picture for everyone, 
        #track_dat = dat.trackInfos[i_loc]['localInfos']
        #times.append(len(track_dat)/10)
        
        dists.append(np.sqrt((xs[i_loc] - x0s[i_loc]) ** 2 + (ys[i_loc] - y0s[i_loc]) ** 2))

    dist_avg = np.mean(dists)
    dist_std = np.std(dists)

    # bidi_raw for bidiregression
    bidi_raw_0 = pd.DataFrame({
        'Name': [name] * n_loc,
        'xloc': xs,
        'yloc': ys,
        'xorig': x0s,
        'yorig': y0s,
        'distance': dists
        #'time': times
    })
    bidi_raw = pd.concat([bidi_raw, bidi_raw_0], ignore_index=True)

    # Track_Avg, Track_Std
    track_dist_list = []
    n_loc_track = dat.trackInfos.shape[0]
    for i_loc in range(n_loc_track):
        track_dat = dat.trackInfos[i_loc]['localInfos']
        n_point = len(track_dat)
        x_list = [p['x'] for p in track_dat]
        y_list = [p['y'] for p in track_dat]

        total_dist = sum(((x_list[i] - x_list[i-1]) ** 2 + (y_list[i] - y_list[i-1]) ** 2) ** 0.5 for i in range(1, n_point))
        track_dist_list.append(total_dist)

    mean_track_dist = np.mean(track_dist_list)
    std_track_dist = np.std(track_dist_list)

    # save data
    cal_out = {
        'Name': name,
        'Age': age,
        'Sex': sex,
        'Test_date': test_date,
        'Duration': time_dur,
        'Dist_Avg': dist_avg,
        'Dist_Std': dist_std,
        'Track_Avg': mean_track_dist,
        'Track_Std': std_track_dist
    }

    results.append(cal_out)
    print(f"Processed {subjid}")

# to DataFrame and save file
df = pd.DataFrame(results)
df.to_csv(cal_save_path, index=False)
bidi_raw.to_csv(bidi_save_path, index=False)

print(f"Saved combined results to {save_folder}")
# Out:
# Processed baoran_20240305-08-23-25
# Processed caichenyang_20240119-06-09-29
# Processed chenanqi_20240305-07-28-40
# Processed chengquan_20231220-05-33-06
# Processed chenqiyang_20231220-01-18-34
# Processed chenrouhan_20240228-04-54-24
# Processed chenxintong_20240302-11-38-19
# Processed chenxin_20240229-08-20-58
# Processed chenyingqi_20231201-04-43-56
# Processed chenzhedong_20240118-03-40-27
# Processed daiweitao_20240115-07-37-35
# Processed dengrudan_20240118-06-05-14
# Processed dengyang_20240229-06-16-15
# Processed dingxukai_20240123-05-03-40
# Processed duanjinghui_20240117-07-15-43
# Processed dufeixuan_20240303-09-41-09
# Processed dujunan_20240229-06-41-53
# Processed dulijun_20240305-06-22-18
# Processed fangjiayi_20231203-12-12-08
# Processed fanzhiliang_20240320-06-44-53
# Processed fuyihan_20231213-06-25-52
# Processed gangchenming_20240302-10-17-49
# Processed gaomeiyi_20231201-02-14-06
# Processed gaoshuolian_20231203-09-46-55
# Processed gaoyushi_20240115-08-25-00
# Processed gesangciren_20240115-06-23-11
# Processed gujun_20240115-07-14-05
# Processed guocong_20231210-11-48-42
# Processed guoyeye_20240302-11-22-44
# Processed hanyue_20240306-07-02-02
# Processed heguirong_20240118-06-18-05
# Processed hejiayi_20231228-08-51-55
# Processed hongbaicheng_20240118-02-53-04
# Processed hongjiayu_20231220-01-12-58
# Processed huangyanran_20240303-09-44-13
# Processed huaxinran_20240119-10-33-13
# Processed hutianfeng_20231213-09-44-45
# Processed jianglai_20240119-06-36-49
# Processed jijiamin_20240118-04-15-56
# Processed jingyubo_20240315-06-08-16
# Processed jinxinyue_20240305-08-41-05
# Processed kepeirui_20240303-09-24-30
# Processed leiyu_20240115-07-58-59
# Processed liaojiaming_20240228-04-46-18
# Processed lihenghui_20231213-09-58-31
# Processed lijialin_20240118-04-47-19
# Processed lijuanyu_20240229-12-14-55
# Processed limingze_20240228-05-01-16
# Processed linyi_20240115-06-01-38
# Processed linzhenghui_20231213-06-30-00
# Processed linzijing_20240306-08-17-54
# Processed liumingting_20231213-12-01-44
# Processed liusongting_20231213-10-57-25
# Processed liuwanqing_20240303-11-50-35
# Processed liuxiangyi_20231201-01-24-20
# Processed liuyuting_20240115-06-56-27
# Processed liuyutong_20231201-04-36-18
# Processed liuzhanxu_20231228-05-45-38
# Processed liyufeng_20240118-05-45-05
# Processed luzhangjing_20240309-10-25-32
# Processed maluyang_20240306-06-30-28
# Processed maoshenpei_20240118-03-50-50
# Processed maxin_20240123-03-04-33
# Processed meishaoxian_20240315-06-26-46
# Processed murediliabula_20240302-11-33-07
# Processed niejingting_20231203-10-55-27
# Processed ouyangjing_20240309-11-41-46
# Processed panyiying_20240306-06-37-20
# Processed qianjiajun_20231220-02-53-59
# Processed qiantaiming_20240302-10-50-30
# Processed qijiahao_20240115-06-39-24
# Processed qiumingen_20231201-03-31-11
# Processed qiuzixuan_20240123-04-02-05
# Processed renminfeng_20240229-07-32-21
# Processed shixuanxuan_20231228-06-18-50
# Processed sunyuewei_20240306-06-17-17
# Processed suzhe_20240313-06-31-28
# Processed tangminke_20240309-12-21-24
# Processed tangxinai_20231203-11-06-42
# Processed tangyi_20240104-06-03-08
# Processed tangyufei_20231213-10-16-57
# Processed tangzhucan_20240229-11-59-12
# Processed tanxinyi_20240302-10-41-47
# Processed taolv_20240315-07-04-55
# Processed tengyujie_20240306-06-33-16
# Processed tukai_20231213-12-12-18
# Processed tulugenaiyi_20231208-04-26-48
# Processed wangfangqi_20240309-09-13-23
# Processed wanghongru_20240314-09-19-00
# Processed wangjingen_20231201-04-03-50
# Processed wangjunbin_20240228-01-52-48
# Processed wangqian_20231210-11-59-05
# Processed wangshiming_20240306-06-59-47
# Processed wangwenqi_20231201-02-02-46
# Processed wangxiaoxiao_20240229-07-11-27
# Processed wangying_20231203-10-38-33
# Processed weiriwei_20240118-02-49-40
# Processed wuminqin_20240118-06-11-10
# Processed wuzhiwei_20240229-06-30-49
# Processed wuzunan_20240314-06-22-23
# Processed xianghuiru_20231228-06-03-44
# Processed xiazhenyang_20240309-09-29-41
# Processed xingyiyang_20231213-07-17-31
# Processed xiongtianyu_20231223-06-41-11
# Processed xuejia_20240309-11-58-11
# Processed xujiawei_20240306-07-14-08
# Processed xulingna_20240116-06-40-16
# Processed xuyuyi_20240309-10-57-37
# Processed yangchenyi_20231223-06-09-30
# Processed yangdong_20240302-11-43-35
# Processed yangkun_20240305-08-48-47
# Processed yangqian_20231220-03-37-11
# Processed yangzhanchao_20240228-04-34-39
# Processed yantianran_20231228-09-54-01
# Processed Yehaiqing_20240122-11-36-57
# Processed yejiawen_20231208-04-43-47
# Processed yexinying_20231210-11-29-34
# Processed yeziyu_20240309-10-49-28
# Processed yujunjie_20240104-05-44-57
# Processed yumingyue_20231208-04-23-24
# Processed yushengyi_20231213-12-19-13
# Processed yuzihan_20240104-06-32-13
# Processed zengzilu_20240229-08-17-16
# Processed zhangjieyu_20240306-06-34-06
# Processed zhangkejiong_20231223-05-47-03
# Processed zhangsikun_20240315-08-00-58
# Processed zhangxiaoning_20231213-06-32-07
# Processed zhangxiaoqi_20231210-11-19-43
# Processed zhangyixi_20240120-06-51-16
# Processed zhangyixuan_20231215-07-03-59
# Processed zhangzhihao_20240228-04-56-26
# Processed zhangzihan_20240303-11-24-36
# Processed zhangzihao_20231208-04-14-57
# Processed zhangzijiao_20240306-06-46-01
# Processed zhengjinqi_20240229-09-17-14
# Processed zhengxinying_20231203-10-53-08
# Processed zhouhuiling_20231223-06-17-01
# Processed zhoujiameng_20240315-08-10-22
# Processed zhoutianyu_20240302-11-39-07
# Processed zhouwenqing_20231228-07-07-52
# Processed zhouyujia_20231201-06-01-39
# Processed zhubinger_20240228-02-28-58
# Processed zhuyixuan_20240120-07-50-53
# Processed zhuzhiyuan_20240305-06-43-35
# Processed zijuansen_20240303-09-24-26
# Saved combined results to /bigvault/Projects/sea_hero/LOCdata/article/Remap_article/results/data/laosheng_s2

# %%
# freshman_s1
# set dir
parent_folder = '/bigvault/Projects/sea_hero/LOCdata/BEHAVIOR/bulidmap/freshman_s1'
save_folder = '/bigvault/Projects/sea_hero/LOCdata/article/Remap_article/results/data/freshman'
os.makedirs(save_folder, exist_ok=True)

cal_save_path = os.path.join(save_folder, 'cal_dist.csv')
bidi_save_path = os.path.join(save_folder, 'bidi_raw.csv')

subfolders = [f.path for f in os.scandir(parent_folder) if f.is_dir()]

results = []
bidi_raw = pd.DataFrame()

for subfolder in subfolders:
    subjid = os.path.basename(subfolder)

    # read data
    trackinfo_file_path = os.path.join(subfolder, 'trackinfo.txt')
    dat = pd.read_json(trackinfo_file_path)
    userinfo_file_path = os.path.join(subfolder, 'userinfo.txt')
    layout_dat = pd.read_json(userinfo_file_path, orient='index').transpose()

    # basic info
    name = layout_dat['name'][0]
    sex = layout_dat['sex'][0]

    # age
    dob = layout_dat['dateOfBirth'][0]
    dob_year = int(dob[:4])
    dob_month = int(dob[4:6])
    test_time = layout_dat['beginTime'][0]
    test_year = int(test_time.split('/')[0])
    test_month = int(test_time.split('/')[1])
    age = round((test_year - dob_year) + (test_month - dob_month) / 12.0, 1)

    # Test_date
    test_time_dt = datetime.strptime(test_time, "%Y/%m/%d %H:%M:%S")
    test_date = test_time_dt.strftime("%Y/%m/%d")

    # Duration
    time_start = datetime.strptime(layout_dat['beginTime'][0], '%Y/%m/%d %H:%M:%S')
    time_end = datetime.strptime(layout_dat['endTime'][0], '%Y/%m/%d %H:%M:%S')
    time_dur = (time_end - time_start).total_seconds()


    # Dist_Avg, Dist_Std
    n_loc = len(layout_dat['localInfos'][0])
    xs, ys, x0s, y0s, dists = [], [], [], [], []

    for i_loc in range(n_loc):
        xs.append(layout_dat['localInfos'][0][i_loc]['x'])
        ys.append(layout_dat['localInfos'][0][i_loc]['y'])
        x0s.append(layout_dat['targetInfos'][0][i_loc]['x'])
        y0s.append(layout_dat['targetInfos'][0][i_loc]['y'])

        #time for each picture for everyone, 
        #track_dat = dat.trackInfos[i_loc]['localInfos']
        #times.append(len(track_dat)/10)
        
        dists.append(np.sqrt((xs[i_loc] - x0s[i_loc]) ** 2 + (ys[i_loc] - y0s[i_loc]) ** 2))

    dist_avg = np.mean(dists)
    dist_std = np.std(dists)

    # bidi_raw for bidiregression
    bidi_raw_0 = pd.DataFrame({
        'Name': [name] * n_loc,
        'xloc': xs,
        'yloc': ys,
        'xorig': x0s,
        'yorig': y0s,
        'distance': dists
        #'time': times
    })
    bidi_raw = pd.concat([bidi_raw, bidi_raw_0], ignore_index=True)

    # Track_Avg, Track_Std
    track_dist_list = []
    n_loc_track = dat.trackInfos.shape[0]
    for i_loc in range(n_loc_track):
        track_dat = dat.trackInfos[i_loc]['localInfos']
        n_point = len(track_dat)
        x_list = [p['x'] for p in track_dat]
        y_list = [p['y'] for p in track_dat]

        total_dist = sum(((x_list[i] - x_list[i-1]) ** 2 + (y_list[i] - y_list[i-1]) ** 2) ** 0.5 for i in range(1, n_point))
        track_dist_list.append(total_dist)

    mean_track_dist = np.mean(track_dist_list)
    std_track_dist = np.std(track_dist_list)

    # save data
    cal_out = {
        'Name': name,
        'Age': age,
        'Sex': sex,
        'Test_date': test_date,
        'Duration': time_dur,
        'Dist_Avg': dist_avg,
        'Dist_Std': dist_std,
        'Track_Avg': mean_track_dist,
        'Track_Std': std_track_dist
    }

    results.append(cal_out)
    print(f"Processed {subjid}")

# to DataFrame and save file
df = pd.DataFrame(results)
df.to_csv(cal_save_path, index=False)
bidi_raw.to_csv(bidi_save_path, index=False)

print(f"Saved combined results to {save_folder}")
# Out:
# Processed chenshengjie_20231109-06-03-50
# Processed chenxinyi_20231026-11-06-43
# Processed fangzhiming_20231026-01-29-36
# Processed fengloufei_20231024-06-55-10
# Processed fengyinglin_20231020-10-17-26
# Processed guoduxiao_20231027-01-20-09
# Processed heyijun_20231118-08-34-37
# Processed huangmingyang_20231118-10-31-35
# Processed huangxun_20231102-02-12-57
# Processed hugeliang_20231110-02-14-19
# Processed huxiaolong_20231027-06-17-48
# Processed jiangxinyang_20231110-04-13-47
# Processed jiangyu_20231027-03-12-11
# Processed jichengyuan_20231103-10-57-33
# Processed kongdeyu_20231031-10-51-45
# Processed linsiyan_20231102-01-12-33
# Processed lishuyi_20231102-03-18-45
# Processed luyi_20231027-08-12-26
# Processed lvlingtao_20231101-11-01-21
# Processed malihu_20231102-04-20-11
# Processed qianying_20231103-09-35-35
# Processed qinqin_20231101-06-13-22
# Processed shenzhanghao_20231103-01-22-06
# Processed songyiren_20231027-02-34-42
# Processed tumarisi_20231025-10-54-35
# Processed wangjiaqi_20231103-10-17-30
# Processed wangxinlan_20231101-01-19-59
# Processed wangxinrui_20231020-11-06-45
# Processed wutingting_20231027-09-30-02
# Processed wuyiran_20231118-09-14-05
# Processed xiazhiyu_20231110-01-25-39
# Processed xiejiayin_20231103-03-55-31
# Processed xiewenhao_20231102-06-00-01
# Processed xuhaibin_20231027-10-29-04
# Processed xuwenxin_20231103-04-17-28
# Processed yuyihan_20231110-03-39-48
# Processed zhangyuhan_20231123-03-37-47
# Processed zhangzhenchen_20231116-03-51-57
# Processed zhangzhewen_20231110-09-41-45
# Processed zhaozihan_20231103-03-16-35
# Saved combined results to /bigvault/Projects/sea_hero/LOCdata/article/Remap_article/results/data/freshman
